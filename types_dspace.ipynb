# %%
from pymongo import MongoClient
from IPython.display import JSON
import pandas as pd
from unidecode import unidecode

# %%
def str_normilize(word):
    """
    Normalize a string to lowercase and remove accents.

    Parameters
    ----------
    word : str
        string to be normalized.

    Returns
    -------
    str
        normalized string.
    """
    return unidecode(word).lower().strip().replace(".", "")

# %%
def is_thesis(work_type):
    """
    Check if the work type is a thesis.

    Parameters
    ----------
    work_type : str
        work type.

    Returns
    -------
    bool
        True if the work type is a thesis, False otherwise.
    """
    filters=["tesis","thesis","trabajo de grado","monografia","disertacion","monografia","monograph","bachelor"]
    for t in filters:
        if t in str_normilize(work_type.lower()):
            return True
    return False

# %%
c=MongoClient()
db=c["oxomoc_colombia"]

# %%
cols = sorted([i for i in db.list_collection_names() if "records" in i and "dspace" in i])
cols
# Out:
# ['dspace_areandina_records',
#  'dspace_artesaniasdecolombia_records',
#  'dspace_car_records',
#  'dspace_ccb_records',
#  'dspace_cecar_records',
#  'dspace_ceipa_records',
#  'dspace_ces_records',
#  'dspace_cesa_records',
#  'dspace_corhuila_records',
#  'dspace_cuc_records',
#  'dspace_cun_records',
#  'dspace_ecci_records',
#  'dspace_ecr_records',
#  'dspace_educacionbogota_records',
#  'dspace_eia_records',
#  'dspace_elpoli_records',
#  'dspace_endeporte_records',
#  'dspace_escuelaing_records',
#  'dspace_esdegrepositorio_records',
#  'dspace_fucsalud_records',
#  'dspace_fumc_records',
#  'dspace_ibero_records',
#  'dspace_icesi_records',
#  'dspace_itc_records',
#  'dspace_itfip_records',
#  'dspace_itm_records',
#  'dspace_iue_records',
#  'dspace_javeriana_records',
#  'dspace_juanncorpas_records',
#  'dspace_konradlorenz_records',
#  'dspace_lasalle_records',
#  'dspace_libertadores_records',
#  'dspace_minciencias_records',
#  'dspace_pedagogica_records',
#  'dspace_poligran_records',
#  'dspace_sena_records',
#  'dspace_tdea_records',
#  'dspace_uac_records',
#  'dspace_uamerica_records',
#  'dspace_uao_records',
#  'dspace_ucaldas_records',
#  'dspace_ucatolica_records',
#  'dspace_ucc_records',
#  'dspace_uceva_records',
#  'dspace_ucm_records',
#  'dspace_ucn_records',
#  'dspace_uco_records',
#  'dspace_ucompensar_records',
#  'dspace_ucp_records',
#  'dspace_ucundinamarca_records',
#  'dspace_udca_records',
#  'dspace_udea_records',
#  'dspace_udem_records',
#  'dspace_udes_records',
#  'dspace_udistrital_records',
#  'dspace_uexternado_records',
#  'dspace_ufps_records',
#  'dspace_ugc_records',
#  'dspace_uis_records',
#  'dspace_umanizales_records',
#  'dspace_unab_records',
#  'dspace_unac_records',
#  'dspace_unad_records',
#  'dspace_unal_records',
#  'dspace_unaula_records',
#  'dspace_unbosque_records',
#  'dspace_uniagraria_records',
#  'dspace_uniagustiniana_records',
#  'dspace_uniajc_records',
#  'dspace_uniandes_records',
#  'dspace_unibague_records',
#  'dspace_uniboyaca_records',
#  'dspace_unicartagena_records',
#  'dspace_unicauca_records',
#  'dspace_uniclaretiana_records',
#  'dspace_unicolmayor_records',
#  'dspace_unicomfacauca_records',
#  'dspace_unicordoba_records',
#  'dspace_uniguajira_records',
#  'dspace_unilasallista_records',
#  'dspace_unillanos_records',
#  'dspace_unimayor_records',
#  'dspace_unimeta_records',
#  'dspace_uninorte_records',
#  'dspace_unipiloto_records',
#  'dspace_uniquindio_records',
#  'dspace_uniremington_records',
#  'dspace_unisabana_records',
#  'dspace_unisucre_records',
#  'dspace_unitec_records',
#  'dspace_univalle_records',
#  'dspace_universidadean_records',
#  'dspace_uptc_records',
#  'dspace_urosario_records',
#  'dspace_usb_records',
#  'dspace_usergioarboleda_records',
#  'dspace_usta_records',
#  'dspace_ut_records',
#  'dspace_utadeo_records',
#  'dspace_utb_records',
#  'dspace_utp_records']

# %%
all_types=[]
for col_name in cols:
    col=db[col_name]
    pipeline = [
        {
            "$unwind": "$OAI-PMH.GetRecord.record.metadata.dim:dim.dim:field"
        },
        {
            "$match": {
                "OAI-PMH.GetRecord.record.metadata.dim:dim.dim:field.@element": "type"
            }
        },
        {
            "$group": {
                "_id": "$OAI-PMH.GetRecord.record.metadata.dim:dim.dim:field.#text"
            }
        },
        {
            "$project": {
                "_id": 0,
                "unique_types": "$_id"
            }
        }
    ]
    
    # Ejecutar la consulta
    result = col.aggregate(pipeline)
    
    # Mostrar resultados
    unique_types = [doc['unique_types'] for doc in result]
    all_types.extend(unique_types)

# %%
def get_doc(tipo):
    for col_name in cols:
        col=db[col_name]
        rec = col.find_one({"OAI-PMH.GetRecord.record.metadata.dim:dim.dim:field.@element": "type","OAI-PMH.GetRecord.record.metadata.dim:dim.dim:field.#text":tipo})
        if rec:
            return rec

# %%
all_types = [str_normilize(i) for i in all_types if i]
all_types=list(set(all_types))
len(all_types)
# Out:
# 3246

# %%
rterm=["fu-","pt-","seccion","version","pre-escolar","http","purl","semantics"]
for term in rterm:
    all_types = [i for i in all_types if term not in i ]

# %%
filters=["book","libro","articulo","article","paper","documento","document","monografia","monograph","report",
         "review","revision","ficha","manual","trabajo", "apropiacion","material","object","objeto","caso","project","proyecto","audio","grabación"
        "analisis","investigacion","apropiacion","page","pagina","esquema","work","arte","etno","noticia","thesis","tesis","cuento","mapa",
         "podcast","radio","anal","reseña","curso","nota","product","conferenc","text","infor","memo","obra",
        "produccion","pre-","anima","boletin","capitulo","print","carta","cartilla","guia","cuadern","poema","post","plan","acta",
        "anuario","study","estudio","editorial","video","translation","traduccion","software","ensayo","ponencia","narración",
        "resen","infografia","composicion","bachelor","traduc","data","dato","resume","relato","research","consultoria","disertacion",
        "note","entrevista","folleto","patent","mooc","contribucion","congreso","revista","taller","seminario","event","practica",
        "dossier","coloquio","draft","revisao","aplicativo","web",
        "academic",
 'acuerdo',
 'afiche',
 'agenda',
 'art gallery',
 'articuos evaluados por pares',
 'artigo',
 'artigo de pesquisa',
 'artigo de reflexao',
 'aticulo',
 'bibliography',
 'biografico narrativo',
 'borradores de administracion',
 'busto',
 'cartillero',
 'catalogo',
 'censo',
 'ceramica',
 'cine expandido',
 'coleccion',
 'collection',
 'colofon',
 'colophon',
 'comentario invitado',
 'comites, arbritros, et',
 'comparativo',
 'comunicaciones breves',
 'conjunto escultorico',
 'conjunto escutorico',
 'conservacion',
 'contributiontoperiodical',
 'creacion de redes',
 'creacion o interpretacion',
 'creacion o onterpretacion',
 'debate',
 'decreto',
 'desarrollo tecnologico e innovacion',
 'diagnostico',
 'diagnostico bioquimico por tincion de filipin',
 'diagnostico territorial',
 'diagrama',
 'diario',
 'dibujo',
 'docencia - lectura critica',
 'doss-cr',
 'draf',
 'encuentro',
 'encuentro interdisciplinario',
 'encuesta',
 'encuesta corta',
 'encuesta; observacion directa',
 'encuestas',
 'encuestas a turistas en distintas rutas gastronomicas',
 'ensamble escultorico',
 'errata',
 'erratum',
 'escultura',
 'escultura - talla',
 'escultura pedestre',
 'estatutos',
 'fe de erratas',
 'flujograma',
 'foro',
 'fotografia',
 'fotografias',
 'generacion de nuevo conocimiento: otra publicacion divulgativa',
 'glosario',
 'grabacion sonora',
 'grabaciones sonoras',
 'grafico y simulacion',
 'hermeneutico',
 'hermeneutico, cualitativo',
 'hipermedia narrativo',
 'historia de los imperios; historia cultural de la ciencia',
 'historiografico',
 'image',
 'image, 3-d',
 'imagen',
 'imagen fija',
 'imagen fotografia',
 'imagenes',
 'imagenfotografia',
 'instrucciones a los autores',
 'instructions',
 'interactive resource',
 'interactiveresource',
 'interdisciplinario',
 'internship',
 'interview',
 'investigacao qualitativa',
 'investigacion',
 'investigation',
 'investigative section',
 'investigativo',
 'investiugacion accion educativa',
 'invetigacion cualitativa',
 'journal',
 'lectura',
 'lecturas criticas',
 'legal y contenidos',
 'letter',
 'librillo',
 'literatura gris',
 'magazine',
 'manuscript',
 'manuscripts',
 'manuscrito',
 'map',
 'marco logico',
 'marcos logicos',
 'micrositio',
 'modelo a escala',
 'modelos y prototipos',
 'montaje',
 'montaje escenico',
 'multimedia resource',
 'musical composition',
 'narracion transmedia',
 'netart',
 'norma legal',
 'obituario',
 'other',
 'otre',
 'otro',
 'otros',
 'participacion ciudadana',
 'partitura',
 'partituras',
 'pasantia',
 'performance',
 'periodico',
 'photography',
 'pintura',
 'placa',
 'plataforma web',
 'plegable',
 'poa',
 'portal web',
 'programa radial',
 'protocol',
 'protocolo',
 'protocolos',
 'publicacion academica',
 'publicacion seriada',
 'publisher',
 'recording, oral',
 'reda',
 'referencia bibliografica',
 'referencial',
 'reflection',
 'reflexion',
 'reflexion academica',
 'registro de performance',
 'regulaciones, normas, reglamentos o legislaciones',
 'resolucion',
 'resolucion|',
 'sitio web',
 'stillimage',
 'talla',
 'taxonomia',
 'trajo de grado',
 'website',
]
filtered=[]
for p in all_types:
    for f in filters:
        if f in p :
            filtered.append(p)
len(filtered)
#all_types = list(set(all_types)-set(filtered))
# Out:
# 1959

# %%
filter_works=["book","libro","articulo","article","paper","monografia","monograph","report",
         "thesis","tesis","capitulo","bachelor",
        "note"]

# %%
len(filtered)
# Out:
# 1959

# %%
len(set(filtered))
# Out:
# 1182

# %%
post_filters=["la investigacion","la presen"]
for term in post_filters:
    filtered = [i for i in filtered if i not in term]

# %%
len(filtered)
# Out:
# 1957

# %%
filtered = list(set(filtered))
len(filtered)
# Out:
# 1181

# %%
set(all_types)-set(filtered)
# Out:
# {'"actividad antioxidante de variedades de cannabis del cauca - colombia"',
#  '"antioxidant activity of cannabis varieties from cauca - colombia"',
#  '"efectos tributarios y su propagacion sobre los sectores economicos de colombia"',
#  '"tax effects and its propagation over the colombia economics sectors"',
#  '"the carrot and its export potential in alemania"',
#  '"txt"',
#  '1',
#  '150',
#  '170',
#  '2019',
#  'abduccion',
#  'abstract',
#  'acceso restringido',
#  'accion',
#  'accompaniment, catholic church, person, drug addiction, marijuana, alcohol',
#  'acompanamiento, iglesia, persona, drogadiccion, marihuana, alcohol',
#  'actividad_interactiva',
#  'activo',
#  'additives, metabolism, supplementation',
#  'aditivos, metabolismo, suplementacion',
#  'alta',
#  'altorrelieve',
#  'america latina',
#  'antioquia',
#  'antropologico',
#  'aplicado',
#  'application/pdf',
#  'applied',
#  'archivo en pdf',
#  'archivos comprimidos',
#  'archivos visuales',
#  'archivos word',
#  'area agricola',
#  'area ambiental',
#  'area pecuaria',
#  'ariculo',
#  'arqueologico',
#  'articulate',
#  'articulista invitado',
#  'asignatura: desarrollo de habilidades del pensamiento infantil 1',
#  'autor',
#  'baja',
#  'balance de gestion',
#  'betacam sp',
#  'betacam x30',
#  'boyacensismos',
#  'cancer, intervencion psicologica, cancer de cuello uterino, tecnicas de intervencion',
#  'cancer, psychological intervention, cervical cancer, intervention techniques',
#  'caracter cuantitativo, de tipo descriptivo transversal',
#  'carbohidratos, diabetes, lista de   intercambios, macronutrientes',
#  'carbohydrates, diabetes, exchange list, macronutrients',
#  'carbon',
#  'caridad, misericordia, projimidad, relaciones, bien comun',
#  'carpeta',
#  'carpeta de diseno',
#  'carpeta de oficio',
#  'cead_-_popayan',
#  'chapter',
#  'charity, mercy, neighborliness, relationships, common benefit',
#  'cientifico',
#  'cientifico - cuantitativo',
#  'cientifico- social',
#  'cientifico-tecnico',
#  'cinta estereofonica',
#  'cinta magnetica',
#  'clones, enfermedad de chagas, sueros chagasicos cronicos, tamizaje, trypanosoma cmzi',
#  'cognitive disability, nonverbal behaviors, facial expression, physical contact',
#  "computer's science",
#  'con correcciones',
#  'contenido',
#  'control estadistico de procesos',
#  'correlacional',
#  'corte transversal',
#  'creditos',
#  'creditos de posgrado',
#  'creditos por posgrado',
#  'creditos y contenido',
#  'creditos_por_posgrado',
#  'credits',
#  'cualitativa',
#  'cualitativo',
#  'cualitativo - cuantitativo',
#  'cualitativo y cuantitativo',
#  'cualitativo, hermenutico',
#  'cualitativo-cuantitativo',
#  'cualitativo;cuantitativo',
#  'cuantiativo; cualitativo; grupos de discusion',
#  'cuantitativa',
#  'cuantitativo',
#  'cuantitativo y cualitativo',
#  'cuantitativo, aplicado y descriptivo',
#  'cuantitativo, descriptivo',
#  'cuantitativo; cualitativo',
#  'cuantitativo; descriptivo-correlacional',
#  'cuantitativo; descriptivo; exploratorio',
#  'cyc',
#  'desarrollo de la competencia discursiva oral en basica primaria: mediacion a traves de las tic',
#  'descrioptivo corte transversal',
#  'descriptiva',
#  'descriptivo',
#  'descriptivo correlacional',
#  'descriptivo no experimental cuantitativo',
#  'descriptivo observacional retrospectivo',
#  'descriptivo y grupos de discusion',
#  'descriptivo; reflexivo',
#  'descrptivo observacional retrospectivo',
#  'development of oral discursive competence in elementary school: mediation through tic',
#  'didactica y pedagogia',
#  'digital',
#  'dinamica de sistemas',
#  'diplomado',
#  'diplomado de profundizacion',
#  'diplomado de profundizacion de grado',
#  'diplomado de profundizacion para grado',
#  'discapacidad cognitiva, conductas no verbales, expresion facial, contacto fisico',
#  'discusion conceptual',
#  'disparidad de genero',
#  'divulgacion publica de la ciencia',
#  'doctorado',
#  'dvcam',
#  'ecologia',
#  'ecologico',
#  'economia regional',
#  'educacao comparada',
#  'educacion profesional, competencia etica, humanismo y universidad',
#  'educacion: licenciatura en educacion infantil -distancia',
#  'el aleteo azul de la mariposa',
#  'empirico',
#  'en publicacion',
#  'enfoque cualitativo',
#  'enfoque de las capacidades',
#  'enfoque descriptivo',
#  'enfoque exploratorio',
#  'enfoque metodologico de caracter cuantitativo de tipo descriptivo correlacional',
#  'enfoque mixto',
#  'enfoque socioecologico',
#  'english',
#  'espanol',
#  'especializacion',
#  'esperiencia de aula',
#  'esperimental',
#  'estimacion',
#  'estudo teorico',
#  'evaluado por pares',
#  'examen',
#  'experiencia',
#  'experiencia de aula',
#  'experiencia educativa',
#  'experiencia profesional dirigida',
#  'experiencias significativas',
#  'experiment',
#  'experimental',
#  'explicativo',
#  'exploration',
#  'exploratorio',
#  'exploratorio-descriptivo',
#  'exploratory',
#  'fibras',
#  'finalizado',
#  'folder',
#  'fontes orais e bibliograficas',
#  'forrajes',
#  'front matter',
#  'generacion de nuevo conocimiento',
#  'genially',
#  'gestao integral; produtividade; qualitativo',
#  'h5p',
#  'historico',
#  'html - 100 ovas 2021',
#  'html - 12 ovas vimep',
#  'html-12-ovas-vimep',
#  'html-12ovas-vimep',
#  'hueso',
#  'humanista',
#  'in',
#  'indexes and confidence intervals',
#  'indices',
#  'inductivo, cuasiexperimental',
#  'inedito',
#  'ingenieria de sistemas',
#  'instalacion',
#  'instalacion electronica interactiva inmersiva',
#  'institucional',
#  'intellectum repositorio universidad de la sabana',
#  'interactive',
#  'interpretativa',
#  'investigacion',
#  'iseazy author',
#  'jose, virtud, silencio, iglesia, ensenanza',
#  'joseph, virtue, silence, church, teaching',
#  'juego',
#  'l',
#  'la constitucion de bayona',
#  'la teologia al servicio del hombre de hoy: conflicto, ciencia y salud',
#  'licencia',
#  'linea del tiempo',
#  'listado',
#  'listado de organizaciones',
#  'litico',
#  'logit regression; labour economics',
#  'longitudinal',
#  'los aforismos del joven arciniegas',
#  'loss, spirituality, ignatian discernment',
#  'madera',
#  'maestria',
#  'maestria en derecho de estado con enfasis en derecho publico',
#  'marin pelaez, jhon alejandro',
#  'mathematization; modeling; scalelength; mathematical model; unit of measure',
#  'matriz',
#  'matriz de compromisos',
#  'matriz diligenciada',
#  'matriz resultados finales',
#  'medalla',
#  'mercadeo social',
#  'metal',
#  'metalinguistico, neuropsicologico',
#  'methods',
#  'metodo cualitativo',
#  'metodo cualitativo, enfoque critico',
#  'metodo cualitativo; descriptivo',
#  'metodo cuantitativo',
#  'metodo dogmatico del derecho y derecho comparado',
#  'metodo historico y matriz unitaria',
#  'metodo pragmatico, descriptivo e interpretativo, de tipo no experimental y transversal  mixto secuencial exploratorio',
#  'metodologia de la teoria fundamentada propuesta por barney glasser y anselm strauss (1967)',
#  'metodologia mixta',
#  'metodologia mixta, aplicando el diseno secuencial exploratorio',
#  'metodos cualitativos',
#  'microsoft word',
#  'misto',
#  'mix',
#  'mixed',
#  'mixta',
#  'mixto',
#  'mixto; descriptivo',
#  'model',
#  'modelamiento',
#  'modelos matematicos climaticos, de cultivos, y economicos',
#  'morfometrica',
#  'multimedia',
#  'n/a',
#  'na',
#  'navegador',
#  'ninguna',
#  'no aplica',
#  'observacion directa',
#  'observaciones en campo',
#  'openaccess',
#  'original',
#  'ova',
#  'pares evaluadores',
#  'pdf',
#  'pdf, rar',
#  'perdida, espiritualidad, discernimiento ignaciano',
#  'persons with disability, inclusion, sports, social environment',
#  'pesquisa-accion',
#  'plataforma estrategica, diseno de estrategias, matrices cuantitativas, objetivo smart, estructura organizacional',
#  'powerpoint',
#  'pregrado',
#  'preliminares',
#  'preliminaries',
#  'premio nobel de economia; alfred nobel; simon kuznets',
#  'prevencion de embarazos',
#  'prueba de habilidades en la plataforma cisco',
#  'psicologia',
#  'psicometria',
#  'psychology',
#  'publishedveersion',
#  'publishedversio',
#  'quali-quantitative evaluation',
#  'qualitative',
#  'qualitativo',
#  'quality, management systems, calibration/test laboratories, iso 17025 standard',
#  'quantitative',
#  'quantitative, qualitative',
#  'quantitativo',
#  'recomendaciones a los autores',
#  'recommendations to the authors',
#  'reflexivo',
#  'reflexivo e interpretativo',
#  'regresion logistica',
#  'regresion logistica; economia laboral',
#  'relacional y empirica',
#  'reponame: biblioteca digital universidad de antioquia',
#  'restrictedaccess',
#  'retorico',
#  'revisado por pares',
#  'road traffic safety, management system, standard size company, iso39001, key principles, components, risk    management, road safety policy, risk identification, monitoring and evaluation',
#  'sacad',
#  'sacs',
#  'seguridad vial, sistema de gestion, empresa de tamano estandar, iso 39001, principios clave, componentes, gestion de riesgos, politica de seguridad vial, identificacion de riesgos, monitoreo y evaluacion',
#  'service',
#  'simulacion',
#  'simulacion de procesos',
#  'simuladores',
#  'socio-historico',
#  'sonido',
#  'sound',
#  'spa',
#  'spanish',
#  'spatial hedonic price',
#  'tabla',
#  'teacher evaluation in montessori education: a proposed tool',
#  'telecommunications',
#  'telecomunicaciones',
#  'teoria del funcional densidad',
#  'teorica',
#  'teorico',
#  'teorico-empirico',
#  'teorico-historico',
#  'teorico-metodologico',
#  'terminado',
#  'testa',
#  'teste',
#  'testo',
#  'tipo relacional, especulativo; metodo empirico',
#  'tipos de publicacion (controlado)',
#  'title tex oil and human development: the case of tauramena - casanare (2022)',
#  'transformacion genetica bacteriana',
#  'transgresion, orden instituido, castigo, norma, poder',
#  'transgression, instituted order, punishment, norm, power',
#  'triangulacion de metodos cualitatios y cuantitativos',
#  'txt',
#  'u-matic x20',
#  'umatic x30',
#  'umatic x60',
#  'utilizacion de herramientas computacionales',
#  'valor de marca, educacion superior, desercion estudiantil',
#  'valoracion preanestesica en el paciente con enfermedad renal cronica (enfasis en riesgo cardiovascular)',
#  'vhs',
#  'wrod',
#  'zavala, l, verdejo'}

# %%
df=pd.DataFrame()
all_types = [i for i in filtered if i]
all_types=sorted(filtered)
df["source"] = ["dspace"]*len(filtered)
df["tipos_dspace"]=filtered
df.to_excel("tipos_dspace_valid.xlsx")

# %%
filtered
# Out:
# []

# %%
get_doc("PT-002")
# Out:
# {'_id': 'oai:expeditiorepositorio.utadeo.edu.co:20.500.12010/32627',
#  'OAI-PMH': {'@xmlns': 'http://www.openarchives.org/OAI/2.0/',
#   '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   '@xsi:schemaLocation': 'http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd',
#   'responseDate': '2025-01-23T07:36:47Z',
#   'request': {'@verb': 'GetRecord',
#    '@identifier': 'oai:expeditiorepositorio.utadeo.edu.co:20.500.12010/32627',
#    '@metadataPrefix': 'dim',
#    '#text': 'http://expeditiorepositorio.utadeo.edu.co/oai/request'},
#   'GetRecord': {'record': {'header': {'identifier': 'oai:expeditiorepositorio.utadeo.edu.co:20.500.12010/32627',
#      'datestamp': '2023-11-17T21:34:13Z',
#      'setSpec': ['com_20.500.12010_32610',
#       'com_20.500.12010_1897',
#       'com_20.500.12010_18',
#       'col_20.500.12010_32611']},
#     'metadata': {'dim:dim': {'@xmlns:dim': 'http://www.dspace.org/xmlns/dspace/dim',
#       '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#       '@xmlns:doc': 'http://www.lyncode.com/xoai',
#       '@xsi:schemaLocation': 'http://www.dspace.org/xmlns/dspace/dim http://www.dspace.org/schema/dim.xsd',
#       'dim:field': [{'@mdschema': 'dc',
#         '@element': 'contributor',
#         '@qualifier': 'advisor',
#         '#text': 'Sistema de Bibliotecas Universidad de Bogotá Jorge Tadeo Lozano'},
#        {'@mdschema': 'dc',
#         '@element': 'creator',
#         '#text': 'Gómez, Eduardo, 1932'},
#        {'@mdschema': 'dc', '@element': 'date', '#text': '2023'},
#        {'@mdschema': 'dc',
#         '@element': 'date',
#         '@qualifier': 'accessioned',
#         '#text': '2023-11-09T21:17:22Z'},
#        {'@mdschema': 'dc',
#         '@element': 'date',
#         '@qualifier': 'available',
#         '#text': '2023-11-09T21:17:22Z'},
#        {'@mdschema': 'dc',
#         '@element': 'date',
#         '@qualifier': 'created',
#         '#text': '1994-04-28'},
#        {'@mdschema': 'dc',
#         '@element': 'identifier',
#         '@qualifier': 'other',
#         '#text': 'http://www.utadeo.edu.co/es/micrositio/emisora-hjut'},
#        {'@mdschema': 'dc',
#         '@element': 'identifier',
#         '@qualifier': 'uri',
#         '#text': 'http://hdl.handle.net/20.500.12010/32627'},
#        {'@mdschema': 'dc',
#         '@element': 'identifier',
#         '@qualifier': 'repourl',
#         '#text': 'http://expeditiorepositorio.utadeo.edu.co'},
#        {'@mdschema': 'dc',
#         '@element': 'identifier',
#         '@qualifier': 'speed',
#         '#text': '128kbps'},
#        {'@mdschema': 'dc',
#         '@element': 'identifier',
#         '@qualifier': 'soundquality',
#         '#text': 'Buena'},
#        {'@mdschema': 'dc',
#         '@element': 'description',
#         '@qualifier': 'abstract',
#         '#text': 'Lectura del poema dedicado a Góngora y otros poemas del escritor Luis Cernuda.'},
#        {'@mdschema': 'dc',
#         '@element': 'description',
#         '@qualifier': 'hashtag',
#         '#text': '#EmisoraHJUT'},
#        {'@mdschema': 'dc',
#         '@element': 'description',
#         '@qualifier': 'hashtag',
#         '@lang': 'spa',
#         '#text': '#Utadeo'},
#        {'@mdschema': 'dc',
#         '@element': 'format',
#         '@qualifier': 'extent',
#         '#text': '13 minutos'},
#        {'@mdschema': 'dc',
#         '@element': 'format',
#         '@qualifier': 'mimetype',
#         '#text': 'audio/mp3'},
#        {'@mdschema': 'dc', '@element': 'language', '#text': 'Español'},
#        {'@mdschema': 'dc',
#         '@element': 'language',
#         '@qualifier': 'iso',
#         '@lang': 'spa',
#         '#text': 'spa'},
#        {'@mdschema': 'dc',
#         '@element': 'publisher',
#         '#text': 'Universidad de Bogotá Jorge Tadeo Lozano'},
#        {'@mdschema': 'dc',
#         '@element': 'publisher',
#         '@qualifier': 'department',
#         '#text': 'Emisora HJUT 106.9 FM estéreo'},
#        {'@mdschema': 'dc',
#         '@element': 'subject',
#         '#text': 'Cernuda Bidou, Luis, 1902-1963'},
#        {'@mdschema': 'dc', '@element': 'subject', '#text': 'Poesía'},
#        {'@mdschema': 'dc',
#         '@element': 'subject',
#         '#text': 'Poesía -- Colecciones'},
#        {'@mdschema': 'dc',
#         '@element': 'subject',
#         '#text': 'Literatos -- Historia y crítica'},
#        {'@mdschema': 'dc',
#         '@element': 'subject',
#         '#text': 'Escritores -- Historia y crítica'},
#        {'@mdschema': 'dc',
#         '@element': 'subject',
#         '#text': 'Poesía -- Colecciones'},
#        {'@mdschema': 'dc',
#         '@element': 'subject',
#         '#text': 'Literatos -- Historia y crítica'},
#        {'@mdschema': 'dc',
#         '@element': 'subject',
#         '@qualifier': 'keyword',
#         '@lang': 'spa',
#         '#text': 'Famous characters – Enterviews'},
#        {'@mdschema': 'dc',
#         '@element': 'title',
#         '#text': 'Poesía en el tiempo. Programa inspirado en Luis Cernuda'},
#        {'@mdschema': 'dc',
#         '@element': 'type',
#         '@qualifier': 'local',
#         '#text': 'Cinta estereofónica'},
#        {'@mdschema': 'dc',
#         '@element': 'type',
#         '@qualifier': 'local',
#         '#text': 'Cinta Audio 1/4'},
#        {'@mdschema': 'dc',
#         '@element': 'type',
#         '@qualifier': 'local',
#         '#text': 'Programa de radio'},
#        {'@mdschema': 'dc',
#         '@element': 'type',
#         '@qualifier': 'local',
#         '#text': 'PT-002'},
#        {'@mdschema': 'dc',
#         '@element': 'rights',
#         '@qualifier': 'local',
#         '#text': 'Abierto (Texto Completo)'}]}}}}}}
