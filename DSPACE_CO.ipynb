# %%
import pandas as pd
from googlesearch import search # pip install googlesearch-python
import requests
import urllib3
import json
import time
import random

# %%
file_path = "col_ies.xlsx"
data = pd.read_excel(file_path, header=None)
ies_list = data.iloc[:, 0].dropna().tolist()

len(ies_list), ies_list[0]
# Out:
# (326, 'UNIVERSIDAD NACIONAL DE COLOMBIA')

# %%
ies_list_test = ies_list[3:4]

# %%
ies_list_test
# Out:
# ['UNIVERSIDAD DEL CAUCA']

# %%
import urllib3
from googlesearch import search
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse


found_dspace = []
not_found_dspace = set()

# Disable warnings for insecure requests
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)


def reposity_search(query, lang="es", num=5, pause=1):
    try:
        return search(query, lang=lang, num_results=num, sleep_interval=pause)
    except Exception as e:
        raise RuntimeError(f"Error performing search for query '{query}': {e}")

def reposity_urls(ies_list):
    # time.sleep(random.uniform(0, 1))
    results = []
    for i, ie in enumerate(ies_list):
        entry = {
            "institution": ie,
            "results": []}
        ie_query = f'{ie.lower().replace(" ", "+")}+dspace'
        try:
            entry["results"] = list(reposity_search(ie_query))
            if entry["results"]:
                print(f"{i} - {entry['institution'].title()} - urls candidates for DSPACE repository have been found.")
            results.append(entry)
        except Exception as e:
            print(f"Error while searching '{ie_query}': {e}")
    return results

def get_ror_id(name):
    url = f"https://api.ror.org/organizations?query={name}"
    
    response = requests.get(url, timeout=240)
    
    if response.status_code == 200:
        data = response.json()
        
        if data.get("items"):
            ror_id = data["items"][0]["id"]
            return ror_id
        else:
            #if for that org name not found
            return "Error: org id not found"
    else:
        return f"Error: {response.status_code}"

def has_oai(url, max_retries=3, timeout=180):
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
            "(KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        )
    }
    suffixes = [
        "/server/oai/",
        "/oai/",
    ]
    for suffix in suffixes:
        retries = 0
        while retries < max_retries:
            try:
                request_url = url.rstrip("/") + suffix + "request?verb=Identify"
                print(request_url)
                req = requests.get(request_url + suffix, verify=False, headers=headers, timeout=180)
                soup = BeautifulSoup(req.text, features="xml")
                namespace = soup.find("OAI-PMH")
                if req.status_code == 200 and namespace:
                    return suffix
            except:
                pass
            retries += 1
    return None

def has_oai_identifiers(url, max_retries=2, timeout=180):
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/91.0.4472.124 Safari/537.36"
        )
    }
    # Possible OAI-PMH suffixes to test
    suffixes = [
        "server/oai/request?verb=ListIdentifiers&metadataPrefix=oai_dc",
        "oai/request?verb=ListIdentifiers&metadataPrefix=oai_dc",
    ]
    for suffix in suffixes:
        # Construct the full URL, ensuring we don't duplicate slashes
        request_url = url.rstrip("/") + "/" + suffix
        retries = 0
        while retries < max_retries:
            try:
                # Send a GET request with specified headers and timeout
                response = requests.get(
                    request_url,
                    verify=False,
                    headers=headers,
                    timeout=180
                )
                if response.status_code == 200:
                    # Parse the XML response with BeautifulSoup
                    soup = BeautifulSoup(response.text, "xml")
                    namespace = soup.find("OAI-PMH")
                    # If <OAI-PMH> is found, we assume it's a valid OAI-PMH endpoint
                    if namespace is not None:
                        return suffix
            except requests.RequestException:
                pass
            retries += 1
    return None

def clean_url(url):
    parsed_url = urlparse(url)
    return f"{parsed_url.scheme}://{parsed_url.netloc}"

def dspace_validation(candidates_urls):
    print(f"\nStarting repository validation: \n")
    endpoints = {}
    for i, candidate in enumerate(candidates_urls):
        for raw_url in candidate["results"]:
            if ".co" not in raw_url or raw_url.count("/") >= 5:
                continue
            url = clean_url(raw_url)
            # Measure the time taken for the request
            start_time = time.time()
            oai_url = has_oai(url)
            if oai_url:
                end_time = time.time()
                oai_identifiers = "" # has_oai_identifiers(url)
                response_time = round(end_time - start_time, 2)
                # Extract institution acronym from URL
                key = f'dspace_{url.split("//")[1].split(".")[1]}'
                if key in endpoints.keys():
                    continue
                endpoints[key] = {
                    "enabled": True,
                    "name": candidate['institution'],
                    "ror": get_ror_id(candidate['institution'].lower()),
                    "url": url + oai_url + "request",
                    "identifiers_url": url + oai_identifiers if oai_identifiers else "",
                    "request_timeout": response_time
                }
                found_dspace.append(candidate['institution'])
                print(f"{i} - {candidate['institution'].title()} - DSPACE repository have been found successfully.")
                not_found_dspace.discard(candidate['institution'])
                break
            else:
                print(f"{i} - {candidate['institution'].title()} - DSPACE repository not been found.")
                not_found_dspace.add(candidate['institution'])
        print("\n")

    return endpoints

def save_to_json(data, filename):
    try:
        with open(filename, 'w', encoding='utf-8') as json_file:
            json.dump(data, json_file, ensure_ascii=False, indent=4)
        print(f"\nLog file successfully saved: {filename}")
    except Exception as e:
        print(f"Failed to save data: {filename}: {e}")

def print_config(name, url, idx_url, org_name, ror, enabled, file):
    file.write(f"endpoints['{name}'] = {{}}\n")
    file.write(f"endpoints['{name}']['enabled'] = {enabled}\n")
    file.write(f"endpoints['{name}']['name'] = '{org_name}'\n")
    file.write(f"endpoints['{name}']['ror'] = '{ror}'\n")
    file.write(f"endpoints['{name}']['url'] = '{url}'\n")
    # file.write(f"endpoints['{name}']['identifiers_url'] = '{idx_url}'\n")
    file.write(f"endpoints['{name}']['metadataPrefix'] = 'dim'\n")
    file.write(f"endpoints['{name}']['rate_limit'] = {{'calls': 10000, 'secs': 1}}\n")
    file.write(f"endpoints['{name}']['checkpoint'] = {{}}\n")
    file.write(f"endpoints['{name}']['checkpoint']['enabled'] = True\n")
    file.write(f"endpoints['{name}']['checkpoint']['selective'] = True\n")
    file.write(f"endpoints['{name}']['checkpoint']['days'] = 30\n")

def get_ror_id(name):
    url = f"https://api.ror.org/organizations?query={name}"
    response = requests.get(url, timeout=240)
    if response.status_code == 200:
        data = response.json()
        if data.get("items"):
            ror_id = data["items"][0]["id"]
            return ror_id
        else:
            #if for that org name not found
            return "Error: org id not found"
    else:
        return f"Error: {response.status_code}"

def main(ies_list):
    print(f"Starting repository search for {len(ies_list)} institutions: \n")
    candidates_urls = reposity_urls(ies_list)
    endpoints = dspace_validation(candidates_urls)
    return endpoints

# %%
# Run script
endpoints = main(ies_list)

save_to_json(endpoints, f"dspace_endpoints_{len(endpoints)}_ies.json")

# Open file for writing and truncate its content
config_file_name = "colombia_config.py"
with open(config_file_name, "w", encoding="utf-8") as file:
    file.truncate(0)  # Ensure the file is empty
    file.write("endpoints = {}\n")
    
    # Iterate over each endpoint and write its configuration
    for key, config in endpoints.items():
        print_config(
            name=key,
            url=config["url"],
            idx_url=config["identifiers_url"],
            org_name=config["name"],
            ror=config["ror"],
            enabled=config["enabled"],
            file=file
        )
    print(f"\nConfig file successfully saved: {config_file_name}")
    
filename = f"not_found_dspace_{len(not_found_dspace)}.json"
with open(filename, 'w', encoding='utf-8') as json_file:
    json.dump(list(not_found_dspace), json_file, ensure_ascii=False, indent=4)
# Out:
# Starting repository search for 326 institutions:
#
# 0 - Universidad Nacional De Colombia - urls candidates for DSPACE repository have been found.
# 1 - Universidad Pedagogica Nacional - urls candidates for DSPACE repository have been found.
# 2 - Universidad Pedagogica Y Tecnologica De Colombia - Uptc - urls candidates for DSPACE repository have been found.
# 3 - Universidad Del Cauca - urls candidates for DSPACE repository have been found.
# 4 - Universidad Tecnologica De Pereira - Utp - urls candidates for DSPACE repository have been found.
# 5 - Universidad De Caldas - urls candidates for DSPACE repository have been found.
# 6 - Universidad De Cordoba - urls candidates for DSPACE repository have been found.
# 7 - Universidad Surcolombiana - urls candidates for DSPACE repository have been found.
# 8 - Universidad De La Amazonia - urls candidates for DSPACE repository have been found.
# 9 - Universidad Militar-Nueva Granada - urls candidates for DSPACE repository have been found.
# 10 - Universidad Tecnologica Del Choco-Diego Luis Cordoba - urls candidates for DSPACE repository have been found.
# 11 - Universidad De Los Llanos - urls candidates for DSPACE repository have been found.
# 12 - Universidad Popular Del Cesar - urls candidates for DSPACE repository have been found.
# 13 - Universidad-Colegio Mayor De Cundinamarca - urls candidates for DSPACE repository have been found.
# 14 - Universidad Del Pacifico - urls candidates for DSPACE repository have been found.
# 15 - Universidad De Antioquia - urls candidates for DSPACE repository have been found.
# 16 - Universidad Del Atlantico - urls candidates for DSPACE repository have been found.
# 17 - Universidad Del Valle - urls candidates for DSPACE repository have been found.
# 18 - Universidad Industrial De Santander - urls candidates for DSPACE repository have been found.
# 19 - Universidad De Cartagena - urls candidates for DSPACE repository have been found.
# 20 - Universidad De Nariño - urls candidates for DSPACE repository have been found.
# 21 - Universidad Del Tolima - urls candidates for DSPACE repository have been found.
# 22 - Universidad Del Quindio - urls candidates for DSPACE repository have been found.
# 23 - Universidad Francisco De Paula Santander - urls candidates for DSPACE repository have been found.
# 24 - Universidad De Pamplona - urls candidates for DSPACE repository have been found.
# 25 - Universidad Del Magdalena - Unimagdalena - urls candidates for DSPACE repository have been found.
# 26 - Universidad De Cundinamarca-Udec - urls candidates for DSPACE repository have been found.
# 27 - Universidad De Sucre - urls candidates for DSPACE repository have been found.
# 28 - Universidad De La Guajira - urls candidates for DSPACE repository have been found.
# 29 - Universidad Distrital-Francisco Jose De Caldas - urls candidates for DSPACE repository have been found.
# 30 - Pontificia Universidad Javeriana - urls candidates for DSPACE repository have been found.
# 31 - Universidad Incca De Colombia - urls candidates for DSPACE repository have been found.
#
#
# http://repositorio.unicauca.edu.co:8080/server/oai/request?verb=Identify
# http://repositorio.unicauca.edu.co:8080/server/oai/request?verb=Identify
# http://repositorio.unicauca.edu.co:8080/server/oai/request?verb=Identify
# http://repositorio.unicauca.edu.co:8080/oai/request?verb=Identify
# 3 - Universidad Del Cauca - DSPACE repository have been found successfully.
#
#
# https://repositorio.utp.edu.co/server/oai/request?verb=Identify
# 4 - Universidad Tecnologica De Pereira - Utp - DSPACE repository have been found successfully.
#
#
# https://repositorio.ucaldas.edu.co/server/oai/request?verb=Identify
# 5 - Universidad De Caldas - DSPACE repository have been found successfully.
#
#
# https://repositorio.unicordoba.edu.co/server/oai/request?verb=Identify
# 6 - Universidad De Cordoba - DSPACE repository have been found successfully.
#
#
# https://www.usco.edu.co/server/oai/request?verb=Identify
# https://www.usco.edu.co/server/oai/request?verb=Identify
# https://www.usco.edu.co/server/oai/request?verb=Identify
# https://www.usco.edu.co/oai/request?verb=Identify
# https://www.usco.edu.co/oai/request?verb=Identify
# https://www.usco.edu.co/oai/request?verb=Identify
# 7 - Universidad Surcolombiana - DSPACE repository not been found.
# https://repositoriousco.co/server/oai/request?verb=Identify
# https://repositoriousco.co/server/oai/request?verb=Identify
# https://repositoriousco.co/server/oai/request?verb=Identify
# https://repositoriousco.co/oai/request?verb=Identify
# https://repositoriousco.co/oai/request?verb=Identify
# https://repositoriousco.co/oai/request?verb=Identify
# 7 - Universidad Surcolombiana - DSPACE repository not been found.
# https://repositorio.minciencias.gov.co/server/oai/request?verb=Identify
# 7 - Universidad Surcolombiana - DSPACE repository have been found successfully.
#
#
#
#
# https://repository.unimilitar.edu.co/server/oai/request?verb=Identify
# 9 - Universidad Militar-Nueva Granada - DSPACE repository have been found successfully.
#
#
# https://www.utch.edu.co/server/oai/request?verb=Identify
# https://www.utch.edu.co/server/oai/request?verb=Identify
# https://www.utch.edu.co/server/oai/request?verb=Identify
# https://www.utch.edu.co/oai/request?verb=Identify
# https://www.utch.edu.co/oai/request?verb=Identify
# https://www.utch.edu.co/oai/request?verb=Identify
# 10 - Universidad Tecnologica Del Choco-Diego Luis Cordoba - DSPACE repository not been found.
#
#
# https://repositorio.unillanos.edu.co/server/oai/request?verb=Identify
# 11 - Universidad De Los Llanos - DSPACE repository have been found successfully.
#
#
# http://repositorio.unicesar.edu.co/server/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/server/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/server/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/oai/request?verb=Identify
# 12 - Universidad Popular Del Cesar - DSPACE repository not been found.
# http://repositorio.unicesar.edu.co/server/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/server/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/server/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/oai/request?verb=Identify
# http://repositorio.unicesar.edu.co/oai/request?verb=Identify
# 12 - Universidad Popular Del Cesar - DSPACE repository not been found.
#
#
# https://repositorio.unicolmayor.edu.co/server/oai/request?verb=Identify
# https://repositorio.unicolmayor.edu.co/server/oai/request?verb=Identify
# https://repositorio.unicolmayor.edu.co/server/oai/request?verb=Identify
# https://repositorio.unicolmayor.edu.co/oai/request?verb=Identify
# 13 - Universidad-Colegio Mayor De Cundinamarca - DSPACE repository have been found successfully.
#
#
# https://repositorio.unipacifico.edu.co/server/oai/request?verb=Identify
# https://repositorio.unipacifico.edu.co/server/oai/request?verb=Identify
# https://repositorio.unipacifico.edu.co/server/oai/request?verb=Identify
# https://repositorio.unipacifico.edu.co/oai/request?verb=Identify
# 14 - Universidad Del Pacifico - DSPACE repository have been found successfully.
#
#
# https://bibliotecadigital.udea.edu.co/server/oai/request?verb=Identify
# https://bibliotecadigital.udea.edu.co/server/oai/request?verb=Identify
# https://bibliotecadigital.udea.edu.co/server/oai/request?verb=Identify
# https://bibliotecadigital.udea.edu.co/oai/request?verb=Identify
# 15 - Universidad De Antioquia - DSPACE repository have been found successfully.
#
#
# https://repositorio.uniatlantico.edu.co/server/oai/request?verb=Identify
# https://repositorio.uniatlantico.edu.co/server/oai/request?verb=Identify
# https://repositorio.uniatlantico.edu.co/server/oai/request?verb=Identify
# https://repositorio.uniatlantico.edu.co/oai/request?verb=Identify
# https://repositorio.uniatlantico.edu.co/oai/request?verb=Identify
# https://repositorio.uniatlantico.edu.co/oai/request?verb=Identify
# 16 - Universidad Del Atlantico - DSPACE repository not been found.
# http://repositorio.uac.edu.co/server/oai/request?verb=Identify
# http://repositorio.uac.edu.co/server/oai/request?verb=Identify
# http://repositorio.uac.edu.co/server/oai/request?verb=Identify
# http://repositorio.uac.edu.co/oai/request?verb=Identify
# 16 - Universidad Del Atlantico - DSPACE repository have been found successfully.
#
#
# https://bibliotecadigital.univalle.edu.co/server/oai/request?verb=Identify
# 17 - Universidad Del Valle - DSPACE repository have been found successfully.
#
#
# https://noesis.uis.edu.co/server/oai/request?verb=Identify
# 18 - Universidad Industrial De Santander - DSPACE repository have been found successfully.
#
#
# https://repositorio.unicartagena.edu.co/server/oai/request?verb=Identify
# 19 - Universidad De Cartagena - DSPACE repository have been found successfully.
#
#
# https://sired.udenar.edu.co/server/oai/request?verb=Identify
# https://sired.udenar.edu.co/server/oai/request?verb=Identify
# https://sired.udenar.edu.co/server/oai/request?verb=Identify
# https://sired.udenar.edu.co/oai/request?verb=Identify
# https://sired.udenar.edu.co/oai/request?verb=Identify
# https://sired.udenar.edu.co/oai/request?verb=Identify
# 20 - Universidad De Nariño - DSPACE repository not been found.
# https://repositorio.minciencias.gov.co/server/oai/request?verb=Identify
#
#
# https://repository.ut.edu.co/server/oai/request?verb=Identify
# 21 - Universidad Del Tolima - DSPACE repository have been found successfully.
#
#
# https://bdigital.uniquindio.edu.co/server/oai/request?verb=Identify
# 22 - Universidad Del Quindio - DSPACE repository have been found successfully.
#
#
# https://repositorio.ufps.edu.co/server/oai/request?verb=Identify
# https://repositorio.ufps.edu.co/server/oai/request?verb=Identify
# https://repositorio.ufps.edu.co/server/oai/request?verb=Identify
# https://repositorio.ufps.edu.co/oai/request?verb=Identify
# 23 - Universidad Francisco De Paula Santander - DSPACE repository have been found successfully.
#
#
# http://repositoriodspace.unipamplona.edu.co/server/oai/request?verb=Identify
# http://repositoriodspace.unipamplona.edu.co/server/oai/request?verb=Identify
# http://repositoriodspace.unipamplona.edu.co/server/oai/request?verb=Identify
# http://repositoriodspace.unipamplona.edu.co/oai/request?verb=Identify
# http://repositoriodspace.unipamplona.edu.co/oai/request?verb=Identify
# http://repositoriodspace.unipamplona.edu.co/oai/request?verb=Identify
# 24 - Universidad De Pamplona - DSPACE repository not been found.
# https://www.unipamplona.edu.co/server/oai/request?verb=Identify
# https://www.unipamplona.edu.co/server/oai/request?verb=Identify
# https://www.unipamplona.edu.co/server/oai/request?verb=Identify
# https://www.unipamplona.edu.co/oai/request?verb=Identify
# https://www.unipamplona.edu.co/oai/request?verb=Identify
# https://www.unipamplona.edu.co/oai/request?verb=Identify
# 24 - Universidad De Pamplona - DSPACE repository not been found.
#
#
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# 25 - Universidad Del Magdalena - Unimagdalena - DSPACE repository not been found.
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# 25 - Universidad Del Magdalena - Unimagdalena - DSPACE repository not been found.
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# 25 - Universidad Del Magdalena - Unimagdalena - DSPACE repository not been found.
#
#
# https://repositorio.ucundinamarca.edu.co/server/oai/request?verb=Identify
# 26 - Universidad De Cundinamarca-Udec - DSPACE repository have been found successfully.
#
#
# https://repositorio.unisucre.edu.co/server/oai/request?verb=Identify
# 27 - Universidad De Sucre - DSPACE repository have been found successfully.
#
#
# https://repositoryinst.uniguajira.edu.co/server/oai/request?verb=Identify
# 28 - Universidad De La Guajira - DSPACE repository have been found successfully.
#
#
# https://repository.udistrital.edu.co/server/oai/request?verb=Identify
# 29 - Universidad Distrital-Francisco Jose De Caldas - DSPACE repository have been found successfully.
#
#
# https://repository.javeriana.edu.co/server/oai/request?verb=Identify
# https://repository.javeriana.edu.co/server/oai/request?verb=Identify
# https://repository.javeriana.edu.co/server/oai/request?verb=Identify
# https://repository.javeriana.edu.co/oai/request?verb=Identify
# 30 - Pontificia Universidad Javeriana - DSPACE repository have been found successfully.
#
#
# https://unincca.edu.co/server/oai/request?verb=Identify
# https://unincca.edu.co/server/oai/request?verb=Identify
# https://unincca.edu.co/server/oai/request?verb=Identify
# https://unincca.edu.co/oai/request?verb=Identify
# https://unincca.edu.co/oai/request?verb=Identify
# https://unincca.edu.co/oai/request?verb=Identify
# 31 - Universidad Incca De Colombia - DSPACE repository not been found.
# https://unincca.edu.co/server/oai/request?verb=Identify
# https://unincca.edu.co/server/oai/request?verb=Identify
# https://unincca.edu.co/server/oai/request?verb=Identify
# https://unincca.edu.co/oai/request?verb=Identify
# https://unincca.edu.co/oai/request?verb=Identify
# https://unincca.edu.co/oai/request?verb=Identify
# 31 - Universidad Incca De Colombia - DSPACE repository not been found.
# https://sie.car.gov.co/server/oai/request?verb=Identify
# 31 - Universidad Incca De Colombia - DSPACE repository have been found successfully.
#
#
# https://repository.usta.edu.co/server/oai/request?verb=Identify
# https://repository.usta.edu.co/server/oai/request?verb=Identify
# https://repository.usta.edu.co/server/oai/request?verb=Identify
# https://repository.usta.edu.co/oai/request?verb=Identify
# 32 - Universidad Santo Tomas - DSPACE repository have been found successfully.
#
#
# https://bdigital.uexternado.edu.co/server/oai/request?verb=Identify
# 33 - Universidad Externado De Colombia - DSPACE repository have been found successfully.
#
#
# https://expeditiorepositorio.utadeo.edu.co/server/oai/request?verb=Identify
# https://expeditiorepositorio.utadeo.edu.co/server/oai/request?verb=Identify
# ...
# https://unisanpablo.edu.co/oai/request?verb=Identify
# https://unisanpablo.edu.co/oai/request?verb=Identify
# https://unisanpablo.edu.co/oai/request?verb=Identify
# 311 - Fundación Universitaria San Pablo - Unisanpablo - DSPACE repository not been found.
# https://unisanpablo.edu.co/server/oai/request?verb=Identify
# https://unisanpablo.edu.co/server/oai/request?verb=Identify
# https://unisanpablo.edu.co/server/oai/request?verb=Identify
# https://unisanpablo.edu.co/oai/request?verb=Identify
# https://unisanpablo.edu.co/oai/request?verb=Identify
# https://unisanpablo.edu.co/oai/request?verb=Identify
# 311 - Fundación Universitaria San Pablo - Unisanpablo - DSPACE repository not been found.
# https://www.instagram.com/server/oai/request?verb=Identify
# https://www.instagram.com/server/oai/request?verb=Identify
# https://www.instagram.com/server/oai/request?verb=Identify
# https://www.instagram.com/oai/request?verb=Identify
# https://www.instagram.com/oai/request?verb=Identify
# https://www.instagram.com/oai/request?verb=Identify
# 311 - Fundación Universitaria San Pablo - Unisanpablo - DSPACE repository not been found.
#
#
# http://www.centrodeestudiosaeronauticos.edu.co/server/oai/request?verb=Identify
# http://www.centrodeestudiosaeronauticos.edu.co/server/oai/request?verb=Identify
# http://www.centrodeestudiosaeronauticos.edu.co/server/oai/request?verb=Identify
# http://www.centrodeestudiosaeronauticos.edu.co/oai/request?verb=Identify
# http://www.centrodeestudiosaeronauticos.edu.co/oai/request?verb=Identify
# http://www.centrodeestudiosaeronauticos.edu.co/oai/request?verb=Identify
# 312 - Centro De Estudios Aeronáuticos - Cea - DSPACE repository not been found.
#
#
# https://utem.edu.co/server/oai/request?verb=Identify
# https://utem.edu.co/server/oai/request?verb=Identify
# https://utem.edu.co/server/oai/request?verb=Identify
# https://utem.edu.co/oai/request?verb=Identify
# https://utem.edu.co/oai/request?verb=Identify
# https://utem.edu.co/oai/request?verb=Identify
# 313 - Unidad Tecnológica Del Magdalena Medio - Utem - - DSPACE repository not been found.
# https://utem.edu.co/server/oai/request?verb=Identify
# https://utem.edu.co/server/oai/request?verb=Identify
# https://utem.edu.co/server/oai/request?verb=Identify
# https://utem.edu.co/oai/request?verb=Identify
# https://utem.edu.co/oai/request?verb=Identify
# https://utem.edu.co/oai/request?verb=Identify
# 313 - Unidad Tecnológica Del Magdalena Medio - Utem - - DSPACE repository not been found.
# https://www.facebook.com/server/oai/request?verb=Identify
# https://www.facebook.com/server/oai/request?verb=Identify
# https://www.facebook.com/server/oai/request?verb=Identify
# https://www.facebook.com/oai/request?verb=Identify
# https://www.facebook.com/oai/request?verb=Identify
# https://www.facebook.com/oai/request?verb=Identify
# 313 - Unidad Tecnológica Del Magdalena Medio - Utem - - DSPACE repository not been found.
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# 313 - Unidad Tecnológica Del Magdalena Medio - Utem - - DSPACE repository not been found.
#
#
# https://manglar.uninorte.edu.co/server/oai/request?verb=Identify
# https://manglar.uninorte.edu.co/server/oai/request?verb=Identify
# https://manglar.uninorte.edu.co/server/oai/request?verb=Identify
# https://manglar.uninorte.edu.co/oai/request?verb=Identify
# https://uanorte.edu.co/server/oai/request?verb=Identify
# https://uanorte.edu.co/server/oai/request?verb=Identify
# https://uanorte.edu.co/server/oai/request?verb=Identify
# https://uanorte.edu.co/oai/request?verb=Identify
# https://uanorte.edu.co/oai/request?verb=Identify
# https://uanorte.edu.co/oai/request?verb=Identify
# 314 - Corporación Universitaria Autónoma Del Norte - DSPACE repository not been found.
#
#
# https://corpocaminos.edu.co/server/oai/request?verb=Identify
# https://corpocaminos.edu.co/server/oai/request?verb=Identify
# https://corpocaminos.edu.co/server/oai/request?verb=Identify
# https://corpocaminos.edu.co/oai/request?verb=Identify
# https://corpocaminos.edu.co/oai/request?verb=Identify
# https://corpocaminos.edu.co/oai/request?verb=Identify
# 315 - Corporacion Tecnica Profesional Caminos Del Suroccidente Colombiano - DSPACE repository not been found.
# https://corpocaminos.edu.co/server/oai/request?verb=Identify
# https://corpocaminos.edu.co/server/oai/request?verb=Identify
# https://corpocaminos.edu.co/server/oai/request?verb=Identify
# https://corpocaminos.edu.co/oai/request?verb=Identify
# https://corpocaminos.edu.co/oai/request?verb=Identify
# https://corpocaminos.edu.co/oai/request?verb=Identify
# 315 - Corporacion Tecnica Profesional Caminos Del Suroccidente Colombiano - DSPACE repository not been found.
# https://www.facebook.com/server/oai/request?verb=Identify
# https://www.facebook.com/server/oai/request?verb=Identify
# https://www.facebook.com/server/oai/request?verb=Identify
# https://www.facebook.com/oai/request?verb=Identify
# https://www.facebook.com/oai/request?verb=Identify
# https://www.facebook.com/oai/request?verb=Identify
# 315 - Corporacion Tecnica Profesional Caminos Del Suroccidente Colombiano - DSPACE repository not been found.
# https://cosurca.coop/server/oai/request?verb=Identify
# https://cosurca.coop/server/oai/request?verb=Identify
# https://cosurca.coop/server/oai/request?verb=Identify
# https://cosurca.coop/oai/request?verb=Identify
# https://cosurca.coop/oai/request?verb=Identify
# https://cosurca.coop/oai/request?verb=Identify
# 315 - Corporacion Tecnica Profesional Caminos Del Suroccidente Colombiano - DSPACE repository not been found.
#
#
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# 316 - Universitaria Del Chicamocha - DSPACE repository not been found.
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# 316 - Universitaria Del Chicamocha - DSPACE repository not been found.
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# 316 - Universitaria Del Chicamocha - DSPACE repository not been found.
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/server/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# https://unich.edu.co/oai/request?verb=Identify
# 316 - Universitaria Del Chicamocha - DSPACE repository not been found.
#
#
# https://unicatolicadelcaribe.edu.co/server/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/server/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/server/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/oai/request?verb=Identify
# 317 - Fundación Universitaria Católica Del Caribe - DSPACE repository not been found.
# https://repositorio.uco.edu.co/server/oai/request?verb=Identify
# https://www.metabiblioteca.com/server/oai/request?verb=Identify
# https://www.metabiblioteca.com/server/oai/request?verb=Identify
# https://www.metabiblioteca.com/server/oai/request?verb=Identify
# https://www.metabiblioteca.com/oai/request?verb=Identify
# https://www.metabiblioteca.com/oai/request?verb=Identify
# https://www.metabiblioteca.com/oai/request?verb=Identify
# 317 - Fundación Universitaria Católica Del Caribe - DSPACE repository not been found.
# https://unicatolicadelcaribe.edu.co/server/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/server/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/server/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/oai/request?verb=Identify
# https://unicatolicadelcaribe.edu.co/oai/request?verb=Identify
# 317 - Fundación Universitaria Católica Del Caribe - DSPACE repository not been found.
# http://repositorio.uac.edu.co/server/oai/request?verb=Identify
# http://repositorio.uac.edu.co/server/oai/request?verb=Identify
# http://repositorio.uac.edu.co/server/oai/request?verb=Identify
# http://repositorio.uac.edu.co/oai/request?verb=Identify
#
#
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/server/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# https://repositorio.unimagdalena.edu.co/oai/request?verb=Identify
# 318 - Institución Universitaria De Santa Marta - DSPACE repository not been found.
# https://x.com/server/oai/request?verb=Identify
# https://x.com/server/oai/request?verb=Identify
# https://x.com/server/oai/request?verb=Identify
# https://x.com/oai/request?verb=Identify
# https://x.com/oai/request?verb=Identify
# https://x.com/oai/request?verb=Identify
# 318 - Institución Universitaria De Santa Marta - DSPACE repository not been found.
#
#
# https://unisalud.unal.edu.co/server/oai/request?verb=Identify
# https://unisalud.unal.edu.co/server/oai/request?verb=Identify
# https://unisalud.unal.edu.co/server/oai/request?verb=Identify
# https://unisalud.unal.edu.co/oai/request?verb=Identify
# https://unisalud.unal.edu.co/oai/request?verb=Identify
# https://unisalud.unal.edu.co/oai/request?verb=Identify
# 319 - Corporación Institución Universitaria Salud Colombia -Unisalud- - DSPACE repository not been found.
# https://www.universidad.edu.co/server/oai/request?verb=Identify
# https://www.universidad.edu.co/server/oai/request?verb=Identify
# https://www.universidad.edu.co/server/oai/request?verb=Identify
# https://www.universidad.edu.co/oai/request?verb=Identify
# https://www.universidad.edu.co/oai/request?verb=Identify
# https://www.universidad.edu.co/oai/request?verb=Identify
# 319 - Corporación Institución Universitaria Salud Colombia -Unisalud- - DSPACE repository not been found.
# https://www.saludcolombia.edu.co/server/oai/request?verb=Identify
# https://www.saludcolombia.edu.co/server/oai/request?verb=Identify
# https://www.saludcolombia.edu.co/server/oai/request?verb=Identify
# https://www.saludcolombia.edu.co/oai/request?verb=Identify
# https://www.saludcolombia.edu.co/oai/request?verb=Identify
# https://www.saludcolombia.edu.co/oai/request?verb=Identify
# 319 - Corporación Institución Universitaria Salud Colombia -Unisalud- - DSPACE repository not been found.
# https://uunisalud.wordpress.com/server/oai/request?verb=Identify
# https://uunisalud.wordpress.com/server/oai/request?verb=Identify
# https://uunisalud.wordpress.com/server/oai/request?verb=Identify
# https://uunisalud.wordpress.com/oai/request?verb=Identify
# https://uunisalud.wordpress.com/oai/request?verb=Identify
# https://uunisalud.wordpress.com/oai/request?verb=Identify
# 319 - Corporación Institución Universitaria Salud Colombia -Unisalud- - DSPACE repository not been found.
#
#
# https://iuipc.edu.co/server/oai/request?verb=Identify
# https://iuipc.edu.co/server/oai/request?verb=Identify
# https://iuipc.edu.co/server/oai/request?verb=Identify
# https://iuipc.edu.co/oai/request?verb=Identify
# https://iuipc.edu.co/oai/request?verb=Identify
# https://iuipc.edu.co/oai/request?verb=Identify
# 320 - Institución Universitaria De Las Culturas Y Las Artes Populares Ipc - DSPACE repository not been found.
# https://iuipc.edu.co/server/oai/request?verb=Identify
# https://iuipc.edu.co/server/oai/request?verb=Identify
# https://iuipc.edu.co/server/oai/request?verb=Identify
# https://iuipc.edu.co/oai/request?verb=Identify
# https://iuipc.edu.co/oai/request?verb=Identify
# https://iuipc.edu.co/oai/request?verb=Identify
# 320 - Institución Universitaria De Las Culturas Y Las Artes Populares Ipc - DSPACE repository not been found.
# https://institutopopulardecultura.edu.co/server/oai/request?verb=Identify
# https://institutopopulardecultura.edu.co/server/oai/request?verb=Identify
# https://institutopopulardecultura.edu.co/server/oai/request?verb=Identify
# https://institutopopulardecultura.edu.co/oai/request?verb=Identify
# https://institutopopulardecultura.edu.co/oai/request?verb=Identify
# https://institutopopulardecultura.edu.co/oai/request?verb=Identify
# 320 - Institución Universitaria De Las Culturas Y Las Artes Populares Ipc - DSPACE repository not been found.
#
#
# https://universitariadebogota.edu.co/server/oai/request?verb=Identify
# https://universitariadebogota.edu.co/server/oai/request?verb=Identify
# https://universitariadebogota.edu.co/server/oai/request?verb=Identify
# https://universitariadebogota.edu.co/oai/request?verb=Identify
# https://universitariadebogota.edu.co/oai/request?verb=Identify
# https://universitariadebogota.edu.co/oai/request?verb=Identify
# 321 - Corporación Universitaria De Bogota -Universitaria De Bogotá - DSPACE repository not been found.
# https://repository.libertadores.edu.co/server/oai/request?verb=Identify
# https://repository.libertadores.edu.co/server/oai/request?verb=Identify
# https://repository.libertadores.edu.co/server/oai/request?verb=Identify
# https://repository.libertadores.edu.co/oai/request?verb=Identify
# https://repository.libertadores.edu.co/oai/request?verb=Identify
# https://repository.libertadores.edu.co/oai/request?verb=Identify
# 321 - Corporación Universitaria De Bogota -Universitaria De Bogotá - DSPACE repository not been found.
#
#
# https://www.bello.gov.co/server/oai/request?verb=Identify
# https://www.bello.gov.co/server/oai/request?verb=Identify
# https://www.bello.gov.co/server/oai/request?verb=Identify
# https://www.bello.gov.co/oai/request?verb=Identify
# https://www.bello.gov.co/oai/request?verb=Identify
# https://www.bello.gov.co/oai/request?verb=Identify
# 322 - Institución Universitaria Pública De Bello - Iupbello - DSPACE repository not been found.
# https://www.universidad.edu.co/server/oai/request?verb=Identify
# https://www.universidad.edu.co/server/oai/request?verb=Identify
# https://www.universidad.edu.co/server/oai/request?verb=Identify
# https://www.universidad.edu.co/oai/request?verb=Identify
# https://www.universidad.edu.co/oai/request?verb=Identify
# https://www.universidad.edu.co/oai/request?verb=Identify
# 322 - Institución Universitaria Pública De Bello - Iupbello - DSPACE repository not been found.
#
#
# https://iditek.edu.co/server/oai/request?verb=Identify
# https://iditek.edu.co/server/oai/request?verb=Identify
# https://iditek.edu.co/server/oai/request?verb=Identify
# https://iditek.edu.co/oai/request?verb=Identify
# https://iditek.edu.co/oai/request?verb=Identify
# https://iditek.edu.co/oai/request?verb=Identify
# 323 - Fundación Universitaria Para La Investigación, El Desarrollo Tecnológico Y La Innovación - Iditek - DSPACE repository not been found.
# https://iditek.edu.co/server/oai/request?verb=Identify
# https://iditek.edu.co/server/oai/request?verb=Identify
# https://iditek.edu.co/server/oai/request?verb=Identify
# https://iditek.edu.co/oai/request?verb=Identify
# https://iditek.edu.co/oai/request?verb=Identify
# https://iditek.edu.co/oai/request?verb=Identify
# 323 - Fundación Universitaria Para La Investigación, El Desarrollo Tecnológico Y La Innovación - Iditek - DSPACE repository not been found.
#
#
#
# Log file successfully saved: dspace_endpoints_114_ies.json
#
# Config file successfully saved: colombia_config.py

# %%
endpoints
